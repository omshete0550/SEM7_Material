# %% [markdown]
# The advertising dataset captures the sales revenue generated with respect to advertisement costs across multiple channels like radio, tv, and newspapers.
# Objectives:
# i.	Understand the Dataset & cleanup (if required).
# ii.	Build Regression model to predict the sales w.r.t attribute tv.
# iii. Also evaluate the model using scores RMSE

# %%
import numpy as np
import pandas as pd

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Cost function (Log Loss)
def compute_cost(X, y, weights):
    m = len(y)
    h = sigmoid(np.dot(X, weights))
    cost = (-1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
    return cost

# Gradient descent
def gradient_descent(X, y, weights, learning_rate, iterations):
    m = len(y)
    cost_history = []

    for i in range(iterations):
        # Make predictions
        h = sigmoid(np.dot(X, weights))

        # Update weights
        weights -= (learning_rate/m) * np.dot(X.T, (h - y))

        # Calculate cost for current iteration
        cost = compute_cost(X, y, weights)
        cost_history.append(cost)

        # Print cost every 100 iterations
        if i % 100 == 0:
            print(f"Iteration {i}: Cost {cost}")
    
    return weights, cost_history

# Predict class labels
def predict(X, weights):
    prob = sigmoid(np.dot(X, weights))
    return [1 if i > 0.5 else 0 for i in prob]

# %%
df = pd.read_csv('./dataset/advertising/advertising.csv')

# %%
# Add intercept term (bias)
X = df[['Radio Ad Budget ($)']].values
y = df['Sales ($)'].values
X = np.c_[np.ones(X.shape[0]), X]  # Adding a column of ones for the intercept term

# Initialize weights
weights = np.zeros(X.shape[1])

# Set hyperparameters
learning_rate = 0.1
iterations = 10000

# Train the logistic regression model
weights, cost_history = gradient_descent(X, y, weights, learning_rate, iterations)
# Out:
# C:\Users\Om Shete\AppData\Local\Temp\ipykernel_13940\4176303727.py:12: RuntimeWarning: divide by zero encountered in log
#   cost = (-1/m) * np.sum(y * np.log(h) + (1 - y) * np.log(1 - h))
# Iteration 0: Cost -inf
# Iteration 100: Cost -inf
# Iteration 200: Cost -inf
# Iteration 300: Cost -inf
# Iteration 400: Cost -inf
# Iteration 500: Cost -inf
# Iteration 600: Cost -inf
# Iteration 700: Cost -inf
# Iteration 800: Cost -inf
# Iteration 900: Cost -inf
# Iteration 1000: Cost -inf
# Iteration 1100: Cost -inf
# Iteration 1200: Cost -inf
# Iteration 1300: Cost -inf
# Iteration 1400: Cost -inf
# Iteration 1500: Cost -inf
# Iteration 1600: Cost -inf
# Iteration 1700: Cost -inf
# Iteration 1800: Cost -inf
# Iteration 1900: Cost -inf
# Iteration 2000: Cost -inf
# Iteration 2100: Cost -inf
# Iteration 2200: Cost -inf
# Iteration 2300: Cost -inf
# Iteration 2400: Cost -inf
# Iteration 2500: Cost -inf
# Iteration 2600: Cost -inf
# Iteration 2700: Cost -inf
# Iteration 2800: Cost -inf
# Iteration 2900: Cost -inf
# Iteration 3000: Cost -inf
# Iteration 3100: Cost -inf
# Iteration 3200: Cost -inf
# Iteration 3300: Cost -inf
# Iteration 3400: Cost -inf
# Iteration 3500: Cost -inf
# Iteration 3600: Cost -inf
# Iteration 3700: Cost -inf
# Iteration 3800: Cost -inf
# Iteration 3900: Cost -inf
# Iteration 4000: Cost -inf
# Iteration 4100: Cost -inf
# Iteration 4200: Cost -inf
# Iteration 4300: Cost -inf
# Iteration 4400: Cost -inf
# Iteration 4500: Cost -inf
# Iteration 4600: Cost -inf
# Iteration 4700: Cost -inf
# Iteration 4800: Cost -inf
# Iteration 4900: Cost -inf
# Iteration 5000: Cost -inf
# Iteration 5100: Cost -inf
# Iteration 5200: Cost -inf
# Iteration 5300: Cost -inf
# Iteration 5400: Cost -inf
# Iteration 5500: Cost -inf
# Iteration 5600: Cost -inf
# Iteration 5700: Cost -inf
# Iteration 5800: Cost -inf
# Iteration 5900: Cost -inf
# Iteration 6000: Cost -inf
# Iteration 6100: Cost -inf
# Iteration 6200: Cost -inf
# Iteration 6300: Cost -inf
# Iteration 6400: Cost -inf
# Iteration 6500: Cost -inf
# Iteration 6600: Cost -inf
# Iteration 6700: Cost -inf
# Iteration 6800: Cost -inf
# Iteration 6900: Cost -inf
# Iteration 7000: Cost -inf
# Iteration 7100: Cost -inf
# Iteration 7200: Cost -inf
# Iteration 7300: Cost -inf
# Iteration 7400: Cost -inf
# Iteration 7500: Cost -inf
# Iteration 7600: Cost -inf
# Iteration 7700: Cost -inf
# Iteration 7800: Cost -inf
# Iteration 7900: Cost -inf
# Iteration 8000: Cost -inf
# Iteration 8100: Cost -inf
# Iteration 8200: Cost -inf
# Iteration 8300: Cost -inf
# Iteration 8400: Cost -inf
# Iteration 8500: Cost -inf
# Iteration 8600: Cost -inf
# Iteration 8700: Cost -inf
# Iteration 8800: Cost -inf
# Iteration 8900: Cost -inf
# Iteration 9000: Cost -inf
# Iteration 9100: Cost -inf
# Iteration 9200: Cost -inf
# Iteration 9300: Cost -inf
# Iteration 9400: Cost -inf
# Iteration 9500: Cost -inf
# Iteration 9600: Cost -inf
# Iteration 9700: Cost -inf
# Iteration 9800: Cost -inf
# Iteration 9900: Cost -inf

# %%
# Predict class labels on the training set (or any test set)
predictions = predict(X, weights)

# Compare the predictions with the actual labels
accuracy = np.mean(predictions == y) * 100
print(f"Training Accuracy: {accuracy:.2f}%")
# Out:
# Training Accuracy: 0.00%
